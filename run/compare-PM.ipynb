# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('run'), '..')))
from py_files import create_brick_catalogue

# %load_ext autoreload
# %autoreload 2

# %%
old_dir = '/pscratch/sd/d/dstn/forced-motions-dr10/forced-brick/000/'
new_dir = '/pscratch/sd/n/nelfalou/original-proper-motions/'

# %%
create_brick_catalogue.create_catalogues(new_dir, old_dir, old_dir, original_data=True)
# Out:
# 0001m032.fits
# /global/u2/n/nelfalou/LegacyPM/py_files/create_brick_catalogue.py:115: RuntimeWarning: divide by zero encountered in divide
#   dra_error = 1 / np.sqrt(dra_ivar)
# /global/u2/n/nelfalou/LegacyPM/py_files/create_brick_catalogue.py:116: RuntimeWarning: divide by zero encountered in divide
#   ddec_error = 1 / np.sqrt(ddec_ivar)
# /global/u2/n/nelfalou/LegacyPM/py_files/create_brick_catalogue.py:64: RuntimeWarning: invalid value encountered in scalar divide
#   ref_mjd = np.sum((dra_ivar * forced.mjd)[obj_filt]) / np.sum(dra_ivar[obj_filt]) # ref_mjd for this dataset is different from Gaia's ref_mjd
# done! now writing to file...
# 0004m392.fits
# done! now writing to file...
# 0001p252.fits
# done! now writing to file...
# 0006m120.fits
# done! now writing to file...
# 0003m705.fits
# done! now writing to file...
# 0001m322.fits
# done! now writing to file...
# 0008m645.fits
# done! now writing to file...
# 0004m312.fits
# done! now writing to file...
# 0001m185.fits
# ...
