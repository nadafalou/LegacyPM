# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('run'), '..')))
from py_files import create_brick_catalogue
from glob import glob


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
old_dir = '/pscratch/sd/d/dstn/forced-motions-dr10/forced-brick/003/'
new_dir = '/pscratch/sd/n/nelfalou/original-proper-motions/003'

# %%
if False:
    create_brick_catalogue.create_catalogues(new_dir, old_dir, old_dir, original_data=True)

# %%
fns = glob('/pscratch/sd/n/nelfalou/original-proper-motions/tractor-original-pm*') 
fns.sort()
len(fns)
# Out:
# 80
